# %%
! pip install langchain-openai
# Out:
# ...
#   Obtaining dependency information for langchain-openai from https://files.pythonhosted.org/packages/07/48/84e1840c25592bb76deea48d187d9fc8f864c9c82ddf3f084da4c9b8a15b/langchain_openai-0.0.6-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for openai<2.0.0,>=1.10.0 from https://files.pythonhosted.org/packages/26/a1/75474477af2a1dae3a25f80b72bbaf20e8296191ece7fff2f67984206f33/openai-1.12.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tiktoken<1,>=0.5.2 from https://files.pythonhosted.org/packages/69/ca/0a71c1cdbf36da977bd306d295042087187954c32bfa259fa7afede0608b/tiktoken-0.6.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI()

# %%
llm.invoke("what is docker and how is it useful for deployment?")
# Out:
# AIMessage(content="Docker is a platform that allows developers to package, distribute, and run applications in containers. Containers are lightweight, portable, and isolated environments that contain everything needed to run an application, including code, runtime, system tools, libraries, and settings. \n\nDocker is useful for deployment for several reasons:\n\n1. Consistency: Docker containers ensure that the application runs consistently across different environments, such as development, testing, and production.\n\n2. Efficiency: Docker containers are lightweight and share the host operating system's kernel, which means they require fewer resources and can be started and stopped quickly.\n\n3. Scalability: Docker allows for easy scaling of applications by running multiple instances of the same container on different hosts.\n\n4. Portability: Docker containers can be easily moved between different environments, such as on-premise servers, cloud servers, and developer laptops.\n\n5
# ...

# %% [markdown]
# # Create Prompt Model

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an English-Hindi translator that returns whatever the user says"),
    ("user", "{input}")
])

# %%
chain = prompt | llm

# %%
chain.invoke({
    "input":"i enjoy going to rock concerts"
})
# Out:
# AIMessage(content='मुझे रॉक कॉन्सर्ट्स जाना अच्छा लगता है।')

# %% [markdown]
# # Add Output Parser To Chain

# %% [markdown]
# ## Output parser means it is a core component of langchain

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
chain.invoke({"input":"I'm currently working at GoodTechMinds as a AI/ML intern"})
# Out:
# 'मैं वर्तमान में GoodTechMinds में AI/ML इंटर्न के रूप में काम कर रहा/रही हूँ।'

# %%
llm.invoke("What is todays date?")
# Out:
# AIMessage(content='Today is October 8, 2021.')

# %% [markdown]
# # We are loading the URL and talks to it

# %% [markdown]
# ## retriveval chain

# %% [markdown]
# ### Here we use a technique named as web scraping

# %% [markdown]
# *That go to a website makes the request and returns the valuable information that we need*

# %%
! pip install beautifulsoup4

# %%
! pip install faiss-cpu
# Out:
# ...
#   Obtaining dependency information for faiss-cpu from https://files.pythonhosted.org/packages/3e/8f/55f8cd863c678a703aa3b97e5f4511cfd2c52987ba05459afdcdec76eeb3/faiss_cpu-1.7.4-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 393.8 kB/s eta 0:00:28
#    ---------------------------------------- 0.1/10.8 MB 573.4 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/10.8 MB 525.1 kB/s eta 0:00:21
#    ---------------------------------------- 0.1/10.8 MB 481.4 kB/s eta 0:00:23
#     --------------------------------------- 0.1/10.8 MB 532.5 kB/s eta 0:00:20
#     --------------------------------------- 0.1/10.8 MB 532.5 kB/s eta 0:00:20
#     --------------------------------------- 0.1/10.8 MB 532.5 kB/s eta 0:00:20
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
loader = WebBaseLoader("https://blog.langchain.dev/langchain-v0-1-0/")
docs = loader.load()

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()

# %%
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(docs)

# %%
documents
# Out:
# [Document(page_content='LangChain v0.1.0\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n                LangChain Blog\n        \n\n\n\n\n\n\nHome\n\n\n\n\nBy LangChain\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nGitHub\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLangChain v0.1.0\n\nBy LangChain\n10 min read\nJan 8, 2024', metadata={'source': 'https://blog.langchain.dev/langchain-v0-1-0/', 'title': 'LangChain v0.1.0', 'language': 'en'}),
# ...

# %%
vectorstore = FAISS.from_documents(documents,embeddings)

# %% [markdown]
# # Create chain for document,ents

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
template = """Answer the following question based only on the provided context:


<context>
{context}
</context>

Questions:{input}

"""
prompt = ChatPromptTemplate.from_template(template)
document_chain = create_stuff_documents_chain(llm,prompt)

# %%
from langchain_core.documents import Document
document_chain.invoke({
    
    "input":"what is langchain 0.1.0?",
    "context": [Document(page_content="langchain 0.1.0 is the new version of llm app development framework?")]
})
# Out:
# 'Langchain 0.1.0 is the new version of the llm app development framework.'

# %% [markdown]
# # Create Retrivel Chain

# %%
from langchain.chains import create_retrieval_chain
retriever = vectorstore.as_retriever()
retrievel_chain = create_retrieval_chain(retriever,document_chain)

# %% [markdown]
# *It featch the query and documents which are similar to my questions*

# %%
response = retrievel_chain.invoke({
    
    "input":"What is new in langchain 0.1.0"
})

# %%
response
# Out:
# {'input': 'What is new in langchain 0.1.0',
# ...

# %%
response['answer']
# Out:
# 'In langchain 0.1.0, there are two large architectural changes: separating out langchain-core and separating out partner packages from langchain. Additionally, a new versioning standard is implemented where any breaking changes to the public API will result in a minor version bump, and bug fixes or new features will result in a patch version bump. This version also focuses on stability, improved focus through functionality and documentation, and better organization of the project.'

# %% [markdown]
# # Conversational retrieval chain

# %%
from langchain.chains import create_history_aware_retriever
from langchain_core.prompts import MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages([
    MessagesPlaceholder(variable_name="chat_history"),
    ("user", "{input}"),
    ("user", "given the above conversation, generate a search query to look up in order to get information relevant to the conversation")
])
retriever_chain = create_history_aware_retriever(llm , retriever,prompt)

# %%
from langchain_core.messages import HumanMessage, AIMessage
chat_history = [
    HumanMessage(content="Is there anything new about Langchain 0.1.0"),
    AIMessage(content="Yes!")

]
retriever_chain.invoke({
    
    "caht_history": chat_history,
    "input":"tell me more about it!"
})
# Out:
# [Document(page_content='ago, we started making some changes we think will improve the robustness, stability, scalability, and general developer experience around integrations. We split out ALL third party integrations into langchain-community â€“ this allows us to centralize integration-specific work. We have also begun to split out individual integrations into their own packages. So far we have done this for ~10 packages, including OpenAI, Google and Mistral. One benefit of this is better dependency management - previously, all dependencies were optional, leading to some headaches when trying to install specific versions. Now if integrations are in their own package, we can more strictly version their requirements, leading to easier installation. Another benefit is versioning. Oftentimes, there are changes to the third party integrations, which require breaking changes. These can now be reflected on an individual integration basis with proper versioning in the standalone integration
# ...

# %%
from langchain.chains import create_retrieval_chain
prompt = ChatPromptTemplate.from_messages([
    ("system", "Answer the user's questions based on the below context:\n\n{context}"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("user", "{input}")
])
document_chain = create_stuff_documents_chain(llm,prompt)
conversational_retrieval_chain = create_retrieval_chain(retriever_chain,document_chain)

# %%
response =conversational_retrieval_chain.invoke({
    'chat_history':[],
    "input":"What is langchain 0.1.0 about?"
})

# %%
response
# Out:
# {'chat_history': [],
#  'input': 'What is langchain 0.1.0 about?',
# ...

# %%
response['answer']
# Out:
# 'LangChain 0.1.0 is the first stable version of the LangChain library. It is fully backwards compatible, available in both Python and JavaScript, and comes with improved functionality and documentation. This release marks a significant milestone for LangChain, as it aims to earn developer trust and provide a foundation for systematic and safe evolution of the library. The versioning policy has been updated to clearly communicate breaking changes and ensure a more structured approach to updates, bug fixes, and new features. Additionally, the release includes architectural changes, such as separating langchain-core and partner packages, to better organize the project and streamline development. The focus is on core abstractions, integrations, agents, observability, and composability, making LangChain the default framework for building LLM applications.'

# %%
from langchain_core.messages import HumanMessage, AIMessage

chat_history = [
    HumanMessage(content="Is there anything new about Langchain 0.1.0"),
    AIMessage(content="Yes!")
]

response = conversational_retrieval_chain.invoke({
    'chat_history': chat_history,
    "input": "Tell me more about it?"
})

# %%
response['answer']
# Out:
# 'Langchain 0.1.0 is the first stable version of the LangChain library. It is fully backwards compatible and comes in both Python and JavaScript versions. This release includes improved focus through both functionality and documentation. The versioning standard for LangChain has also been updated - any breaking changes to the public API will result in a minor version bump, while bug fixes or new features will result in a patch version bump. This update aims to communicate clearly with developers, allow for official deprecation of old code, and handle integrations more responsibly. The release also includes improvements in areas such as retrieval strategies, agent methods, and observability. Additionally, LangChain has introduced LangSmith to provide a best-in-class debugging experience, and LangChain Expression Language (LCEL) for composability, enabling customization of different parts of the orchestration.'
